# %%
print("Hello")
# Out:
# Hello

# %%
a=int(input("enter 1st number"))
b=int(input("enter 2nd number"))
sum=a+b
print("sum of 2 numbers is:",sum)
# Out:
# sum of 2 numbers is: 653

# %%
a=int(input("enter any number"))
if a%2==0:
    print(a,"is an even number")
else:
    print(a,"is an odd number")
# Out:
# 76 is an even number

# %%
a=int(input("enter the 1st number:"))
b=int(input("enter the 2nd number"))
if a>b:
    print(a,"is greater than",b)
else:
    print(b,"is greater than",a)
# Out:
# 87 is greater than 78

# %%
a=int(input("Enter any number"))
if a<0:
    print(a,"is a negative number")
elif a==0:
    print(a,"is 0")
else:
    print(a,"is a positive number")
# Out:
# 456 is a positive number

# %%
n=int(input("Enter the number:"))
count=1
while count<n:
    fact=n*count
    count+=1
print("factorial of number",n,"=",fact)
# Out:
# factorial of number 45 = 1980

# %%
n=input("Enter a two digit number:")
r=n[::-1]
print("reversed number:",r)
# Out:
# reversed number: 55

# %%
list=[]
ans='n'
while ans=='n':
    num=int(input("enter a number:"))
    list.append(num)
    ans=input("do you want to stop(y/n):")
print("original list:",list)
a=[]

while list:
    min=list[0]
    for i in list:
        if min>i:
            min=i
    a.append(min)
    list.remove(min)

print("sorted list:",a)
# Out:
# original list: [64, 765, 7664, 76]
# sorted list: [64, 76, 765, 7664]

# %%
list=eval(input("enter a list of numbers:"))
x=[]
while list:
    max=list[0]
    for i list():
        if max<i:
# Out:
#   Cell In[1], line 5
#     for i list():
#           ^
# SyntaxError: invalid syntax

# %%
class Employee():
    def filldata(self):
        self.name=input("enter the name of the employee:")
        self.id=input("enter employee id:")
        self.salary=input("enter salary:")
    def display(self):
        print("name of the employee:",self.name)
        print("employee id:",self.id)
        print("salary:",self.salary)
a=Employee()
a.filldata()
a.display()
# Out:
# name of the employee: vritika
# employee id: 23
# salary: 100

# %%
class student:
    def __init__(self,my_name,my_roll,my_marks):
        self.name=my_name
        self.roll=my_roll
        self.marks=my_marks
    
    def average(self):
        avrg=sum(self.marks)/len(self.marks)
        return avrg
    
s1=student('vritika',23,[98,82,85,80,78,90])
print(s1.name)
print(s1.average())
# Out:
# vritika
# 85.5

# %%
class subscription:
    def __init__(self,plan,sub_id,payment):
        ...

# %%
class OTTsubscription:
    def __init__(self,sub_id,sub_plan,sub_payment):
        self.id=sub_id
        self.plan=sub_plan
        self.payment=sub_payment
    
    def subscribe(self):
        print(f"subscriber with the {self.id} subscribed to the {self.plan}")
    
    def unsubscribe(self):
        print(f"subscriber with {self.id} unsubscribed the {self.plan}")

class PremiumSubscription(OTTsubscription):
    def __init__(self,sub_id,sub_plan,sub_payment,max_screens):
        super().__init__(sub_id,sub_plan,sub_payment)
        self.screens=max_screens
    
    def max_screens(self,max_screens):
        self.screens=max_screens
        print(f"maixmum screen set to {self.screens} in premium plan")


amazon=PremiumSubscription(342,"yearly",5000,5)
amazon.subscribe()
amazon.max_screens(6)
# Out:
# subscriber with the 342 subscribed to the yearly
# maixmum screen set to 6 in premium plan

# %%
from datetime import datetime,timedelta

class book:
    def __init__(self,b_id,title,author):
        self.b_id=b_id
        self.title=title
        self.auhtor=author
        self.available=True

class member:
    def __init__(self,m_id,name):
        self.m_id=m_id
        self.name=name
        self.bwd_books={}

    def info(self):
        print("member:",self.name)

class student(member):
    def __init__(self,m_id,name):
        super().__init__(m_id,name)
    def info(self):
        print("student:",self.name)

class library:
    def __init__(self):
        self.books={}
        self.members={}

    def add_book(self):
        b_id=int(input("Enter book id:"))
        title=input("Enter book title:")
        author=input("Enter author name:")
        self.books[b_id]=book(b_id,title,author)
        print("Book added.\n")

    def add_member(self):
        m_id=int(input("Enter member id:"))
        name=input("Enter memer name:")
        self.members[m_id]=student(m_id,name)
        print("Member added.\n")

    def borrow_book(self):
        b_id=int(input("enter book id:"))
        m_id=int(input("enter member id:"))

        if b_id in self.books and m_id in self.members==True:
            book=self.books[b_id]
            member=self.members[m_id]
            
            if book.available==True:
                book.availbale=False
                due_date=datetime.now()+timedelta(days=7)
                member.bwd_books[b_id]=due_date
                print("book borrowed. due date is:")
            else:
                print("book is not available \n")
        else:
            print("invalid id!\n")

    def return_book(self):
        b_id=int(input("enter book id:"))
        m_id=int(input("enter member id:"))

        if b_id in self.books and m_id in self.members==True:
            book=self.books[b_id]
            member=self.members[m_id]

            if b_id in member.bwd_books:
                due_date=member.bwd_books.pop(b_id)
                book.available=True

                if datetime.now()>due_date:
                    days_late= ((datetime.now)-due_date).days
                    fine= days_late*5
                    print("late return. fine:",fine, "\n")
                else:
                    print("book returned on time")
            else:
                print("this book was not borrowed by this member \n")
            
    def show_books(self):
        print("\n books list:")
        for book in self.books.values():
            if book.available==True:
                status="available"
            else:
                status="borrowed"
            print(book.b_id,'_',book.title,'_',status)
        print()

    def show_members(self):
        print("\nmembers list:")
        for member in self.members.values():
            print(member.m_id,"-",member.name)
        print()

    def show_borrowers(self):
        print("\n borrowers list:")
        for member in self.members.values():
            if member.bwd_books:
                print(member.name,"-".list(member.bwd_books.keys()))
        print()

    def shoe_overdue(self):
        print("\n overdue books:")
        for member in self.members.values():
            for b_id,due_date in member.bwd_books.items():
                if datetime.now()> due_date:
                    print(member.name,"has overdue book id:",b_id)
        print()

#--------------------------------------MAIN PROGRAM------------------------------------------------------

library= library()

print("1. Add Book")
print("2. Add Member")
print("3. Borrow Book")
print("4. Return Book")
print("5. Show Books")
print("6. Show Members")
print("7. Show Borrowers")
print("8. Show Overdue Books")
print("9. Exit")

while True:
    choice=input("enter your choice:")

    if choice=="1":
        library.add_book()
    elif choice=="2":
        library.add_member()
    elif choice=="3":
        library.borrow_book()
    elif choice=="4":
        library.return_book()
    elif choice=="5":
        library.show_books()
    elif choice=="6":
        library.show_members()
    elif choice=="7":
        library.show_borrowers()
    elif choice=="8":
        library.show_overdue()
    elif choice=="9":
        print("Exiting....Thank You!")
        break
    else:
        print("Invalid Choice!")
# Out:
# 1. Add Book
# 2. Add Member
# 3. Borrow Book
# 4. Return Book
# 5. Show Books
# 6. Show Members
# 7. Show Borrowers
# 8. Show Overdue Books
# 9. Exit
# Book added.
#
# 1. Add Book
# 2. Add Member
# 3. Borrow Book
# 4. Return Book
# 5. Show Books
# 6. Show Members
# 7. Show Borrowers
# 8. Show Overdue Books
# 9. Exit
# Member added.
#
# 1. Add Book
# 2. Add Member
# 3. Borrow Book
# 4. Return Book
# 5. Show Books
# 6. Show Members
# 7. Show Borrowers
# 8. Show Overdue Books
# 9. Exit
# invalid id!
#
# 1. Add Book
# 2. Add Member
# 3. Borrow Book
# 4. Return Book
# 5. Show Books
# 6. Show Members
# 7. Show Borrowers
# 8. Show Overdue Books
# 9. Exit
# Book added.
#
# 1. Add Book
# 2. Add Member
# 3. Borrow Book
# 4. Return Book
# 5. Show Books
# 6. Show Members
# 7. Show Borrowers
# 8. Show Overdue Books
# 9. Exit
# Member added.
#
# 1. Add Book
# 2. Add Member
# 3. Borrow Book
# 4. Return Book
# 5. Show Books
# 6. Show Members
# 7. Show Borrowers
# 8. Show Overdue Books
# 9. Exit
# ...

# %%
from datetime import datetime,timedelta

class book:
    def __init__(self,b_id,title,author):
        self.b_id=b_id
        self.title=title
        self.auhtor=author
        self.available=True

class member:
    def __init__(self,m_id,name):
        self.m_id=m_id
        self.name=name
        self.bwd_books={}

    def info(self):
        print("member:",self.name)

class student(member):
    def __init__(self,m_id,name):
        super().__init__(m_id,name)
    def info(self):
        print("student:",self.name)

class library:
    def __init__(self):
        self.books={}
        self.members={}

    def add_book(self):
        b_id=int(input("Enter book id:"))
        title=input("Enter book title:")
        author=input("Enter author name:")
        self.books[b_id]=book(b_id,title,author)
        print(self.books)
        print("Book added.\n")

    def add_member(self):
        m_id=int(input("Enter member id:"))
        name=input("Enter member name:")
        self.members[m_id]=student(m_id,name)
        print(self.members)
        print("Member added.\n")

    def borrow_book(self):
        b_id=int(input("enter book id:"))
        m_id=int(input("enter member id:"))

        if b_id in self.books and m_id in self.members == True:
            book=self.books[b_id]
            member=self.members[m_id]
            
            if book.available==True:
                book.availbale=False
                due_date=datetime.now()+timedelta(days=7)
                member.bwd_books[b_id]=due_date
                print("book borrowed. due date is:")
            else:
                print("book is not available \n")
        else:
            print("invalid id!\n")

    def return_book(self):
        b_id=int(input("enter book id:"))
        m_id=int(input("enter member id:"))

        if b_id in self.books and m_id in self.members==True:
            book=self.books[b_id]
            member=self.members[m_id]

            if b_id in member.bwd_books:
                due_date=member.bwd_books.pop(b_id)
                book.available=True

                if datetime.now()>due_date:
                    days_late= ((datetime.now)-due_date).days
                    fine= days_late*5
                    print("late return. fine:",fine, "\n")
                else:
                    print("book returned on time")
            else:
                print("this book was not borrowed by this member \n")
            
    def show_books(self):
        print("\n books list:")
        for book in self.books.values():
            if book.available==True:
                status="available"
            else:
                status="borrowed"
            print(book.b_id,'_',book.title,'_',status)
        print()

    def show_members(self):
        print("\nmembers list:")
        for member in self.members.values():
            print(member.m_id,"-",member.name)
        print()

    def show_borrowers(self):
        print("\n borrowers list:")
        for member in self.members.values():
            if member.bwd_books:
                print(member.name,"-".list(member.bwd_books.keys()))
        print()

    def show_overdue(self):
        print("\n overdue books:")
        for member in self.members.values():
            for b_id,due_date in member.bwd_books.items():
                if datetime.now()> due_date:
                    print(member.name,"has overdue book id:",b_id)
        print()

#--------------------------------------MAIN PROGRAM------------------------------------------------------

library= library()

print("1. Add Book")
print("2. Add Member")
print("3. Borrow Book")
print("4. Return Book")
print("5. Show Books")
print("6. Show Members")
print("7. Show Borrowers")
print("8. Show Overdue Books")
print("9. Exit")

while True:
    choice=input("enter your choice:")

    if choice=="1":
        library.add_book()
    elif choice=="2":
        library.add_member()
    elif choice=="3":
        library.borrow_book()
    elif choice=="4":
        library.return_book()
    elif choice=="5":
        library.show_books()
    elif choice=="6":
        library.show_members()
    elif choice=="7":
        library.show_borrowers()
    elif choice=="8":
        library.show_overdue()
    elif choice=="9":
        print("Exiting....Thank You!")
        break
    else:
        print("Invalid Choice!")
# Out:
# 1. Add Book
# 2. Add Member
# 3. Borrow Book
# 4. Return Book
# 5. Show Books
# 6. Show Members
# 7. Show Borrowers
# 8. Show Overdue Books
# 9. Exit
# {23: <__main__.book object at 0x000001B97B974AD0>}
# Book added.
#
# {9: <__main__.student object at 0x000001B97B974EC0>}
# Member added.
#
# Invalid Choice!

# %%
print("hello")
