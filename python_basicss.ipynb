# %%
#even or odd
num = int(input("Enter a number:"))
if num%2 == 0 :
    print(num, "is even")
else :
    print(num, "is odd")
# Out:
# 123 is odd

# %%
#string intput and counting the number of vowels in it
a= str(input("Enter a string :"))
vowels= "aeiouAEIO"
count=0
for char in a:
    if char in vowels:
        count += 1
print("Number of vowels:",count)
# Out:
# Number of vowels: 2

# %%
#largest number in a list
lst=list(map(int,input("Enter numbers with space").split()))
largest= lst[0]
for num in lst:
    if num > largest:
        largest=num
print("Largest number in the lst",largest)
# Out:
# Largest number in the lst 40

# %%
num= int(input("Enter a number:"))
i=0
for i in range(1,11):    
    print("Table of given number:",num, "*",i,"=",num*i)
# Out:
# Table of given number: 23 * 1 = 23
# Table of given number: 23 * 2 = 46
# Table of given number: 23 * 3 = 69
# Table of given number: 23 * 4 = 92
# Table of given number: 23 * 5 = 115
# Table of given number: 23 * 6 = 138
# Table of given number: 23 * 7 = 161
# Table of given number: 23 * 8 = 184
# Table of given number: 23 * 9 = 207
# Table of given number: 23 * 10 = 230

# %%
#object oriented program
#four pillars of OOPs
#1.Encapsulation
#2.Inheritance
#3.Polymorphism
#4.Abstraction
class Student: #student is the name of class created
    name ="Preet"#these are the blue print os class
#__init__ conductor function already exists in the code above but we can add into it
    def __init__(self):
        print("creating new student") #self indicates to the nam of the class given after or object
S= Student()  
print(S)
# Out:
# creating new student
# ...

# %%
class Student:
    college="VGC"
    name="unknown" # this is class.att,obj.att is given higher priority than class attribute 
    
    def __init__(self, name , marks): #def changename can be used to change the name of student from unknown to the name given by user
        college="VGC"
        self.name=name#object attribute that is obj.att
        self.marks=marks  #class attribute contains only one attribute data class.att      
        print("adding new student")
#method is written by the coder
    def welcome(self):
        print("welcome",self.name)
    def getmarks(self):
        return self.marks
S1=Student("Preet", 90)#this is a object of class student and it is stored in variable S1
print(S1)
S2=Student("Manshavi", 90)
print(S2)
S1.welcome()
S1.getmarks()
S1.college
# Out:
# adding new student
# ...
# adding new student
# ...
# welcome Preet
# 'VGC'

# %%
#create a student class that takes name and marks of three subjects as an argument in conductor. then create a method to find average marks of the student and print it
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def find_average(self):
        total = sum(self.marks)
        average = total / len(self.marks)
        print(f"Average marks for {self.name}: {average}")
student1 = Student("Preet", [85, 90, 95])
student1.find_average()
del student1.name
# Out:
# Average marks for Preet: 90.0

# %%
class Account:
   
    def __init__(self, name , acc_num,acc_pass): 
        self.name=name
        self.acc_num=acc_num
        self.__acc_pass=acc_pass #to make the password private we can use __acc_pass instead of acc_pass
        print("creating new account")
    def reset_pass (self):
        print(self.__acc_pass)
account1= Account("Preet", 12345, "password123")
print(account1.acc_pass)# this will give an error because acc_pass is private and cannot be accessed outside the class  
print(account1.reset_pass()) #this will print the password because it is accessed through a method within the class that has access to the private variable
# Out:
# creating new account
# password123
# None

# %%
#inheritance is a feature of object-oriented programming that allows a new class (called a child class or subclass) to inherit properties and behaviors (attributes and methods) from an existing class (called a parent class or superclass). The child class can also have its own unique attributes and methods, in addition to those inherited from the parent class.
class car : #this is the parent class of maruti and tuype class known as base class
    color="black"
    
    def __init__(self,engine):
        self.engine=engine #this is the constructor of thr car class
        
    
    @staticmethod #static method is a decorator used to define a method inside a class that does not require access to the class (via cls) or its instances (via self)
    def start():
        print("car is starting")
         
    @staticmethod # it cannot access or modify class state and they are generally used to perform utility functions when there is no attribute needed
    def stop():
        print("car is stopping") #no attribute

class maruti(car): #maruti is the child class of car class known as derived class 
    def __init__(self,name,model,engine):
        self.name=name
        self.model=model #this is a attribute
        super().__init__(engine) #super()is used to call the constructor of the parent class
        print("creating new car")
        
#till this point this inheritance is a single level inheritance
class types(maruti):#types is the child class of maruti class and grandchild class of car class known as derived class
    def __init__(self,type):
        self.type=type
        
#this is a multilevel inheritance we can add more levels as per choice and it will still be known as multilevel ingheritance       
maruti1= maruti("Maruti", "Swift","2000cc")
maruti2= maruti("Maruti", "800","1500cc")
types1= types("petrol")
print (maruti1.name, maruti1.model, maruti1.engine)
print (maruti2.name, maruti2.model, maruti2.engine)
print(maruti1.start())
print(maruti1.stop())
print(maruti2.color)
print(types1.type)
# Out:
# creating new car
# creating new car
# Maruti Swift 2000cc
# Maruti 800 1500cc
# car is starting
# None
# car is stopping
# None
# black
# petrol

# %%
#multiple inheritance 
class A:
    varA="Welcome to class A"#this is the parent class of class C known as base class
class B:
    varB="Welcome to class B"#this is the parent class of class C known as base class
class C(A,B): #class C is inheriting from both class A and class B this is child class of both class A and class B known as derived class
    varC="Welcome to class C"
c1= C()
print(c1.varA)
print(c1.varB)
print(c1.varC)
# Out:
# Welcome to class A
# Welcome to class B
# Welcome to class C

# %%
#instace method is a method which already exists in code and we acan add more yo it (self)
#class method (cls)
class Person:
    name="unknown"
    
    @classmethod #class method is a method that is bound to the class and not the instance of the class. It takes cls as the first parameter which refers to the class itself   
    def changename(cls,name):
        cls.name = name
        
p1= Person()
print(p1.name)
Person.changename("Preet")
print(p1.name)
print(Person.name)
# Out:
# unknown
# Preet

# %%
#property decorator used to define method/function as a property
#two more decoratoes getter and setter are used to get and set the value of a property respectively
class Student:
    def __init__(self ,sub1,sub2,sub3): 
        self.sub1=sub1
        self.sub2=sub2
        self.sub3=sub3
        
    @property #property decorator is used to define a method as a property which can be accessed like an attribute without calling it as a method
    def percentage(self):
        return str((self.sub1 + self.sub2 + self.sub3)/3) + "%"
student1= Student(85,90,95)
print(student1.percentage)      
student1.sub1=80
print(student1.percentage)
# Out:
# 90.0%
# 88.33333333333333%

# %%
#Polymorphism :opertator overloading
#when the same operator is allowed to have different meanings according to the context.
#operator and dunder functions
#a+b addition         a.__add__(b)
#a-b subtraction      a.__sub__(b)
#a*b multiplication   a.__mul__(b)
#a/b division         a.__truediv__(b)
#a%b modulus          a.__mod__(b)
print(1+2) #this is addition
print("Hello"+" "+"World") #this is string concatenation
print ([1,2]+[3,4]) #this is list concatenation
#in here operator has diff meanings according to context
class complex:
    def __init__(self,real,imag):
        self.real=real
        self.imag=imag
    def shownum(self):
        print(self.real,"i","+",self.imag,"j")
    def __add__(self,other): #this operator allows ua to add 2 num without function .add and can be used
        return complex(self.real + other.real, self.imag + other.imag)
c1= complex(2,3)
c2= complex(4,5)
c1.shownum()
c2.shownum()
c3= c1+c2 #this will call the __add__ method and add the real and imaginary parts of c1 and c2
c3.shownum()
# Out:
# 3
# Hello World
# [1, 2, 3, 4]
# 2 i + 3 j
# 4 i + 5 j
# 6 i + 8 j
